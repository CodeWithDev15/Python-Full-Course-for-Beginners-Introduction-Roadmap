# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
x = pd.read_csv("/Users/rehbarkhan15/Downloads/airquality.csv")

# %%
x.head()
# Out:
#    rownames  Ozone  Solar.R  Wind  Temp  Month  Day
# 0         1   41.0    190.0   7.4    67      5    1
# 1         2   36.0    118.0   8.0    72      5    2
# 2         3   12.0    149.0  12.6    74      5    3
# 3         4   18.0    313.0  11.5    62      5    4
# 4         5    NaN      NaN  14.3    56      5    5

# %%
x.boxplot(column=["Ozone", "Solar.R"])
plt.show()

# %%
x["Ozone"] = x["Ozone"].ffill()

# %%
x["Ozone"].isnull().sum()
x.isnull().sum()
# Out:
# rownames    0
# Ozone       0
# Solar.R     7
# Wind        0
# Temp        0
# Month       0
# Day         0
# dtype: int64

# %%
x.boxplot(column=["Ozone", "Solar.R"])
plt.show()

# %%
x["Solar.R"] = x["Solar.R"].fillna(x["Solar.R"].median())

# %%
x["Solar.R"].isnull().sum()
x.isnull().sum()
# Out:
# rownames    0
# Ozone       0
# Solar.R     0
# Wind        0
# Temp        0
# Month       0
# Day         0
# dtype: int64

# %%
x.boxplot(column=["Ozone", "Solar.R"])
plt.show()

# %%
x.isnull().sum()
# Out:
# rownames    0
# Ozone       0
# Solar.R     0
# Wind        0
# Temp        0
# Month       0
# Day         0
# dtype: int64

# %%
x.head(10)
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   rownames  153 non-null    int64
#  1   Ozone     153 non-null    float64
#  2   Solar.R   153 non-null    float64
#  3   Wind      153 non-null    float64
#  4   Temp      153 non-null    int64
#  5   Month     153 non-null    int64
#  6   Day       153 non-null    int64
# dtypes: float64(3), int64(4)
# memory usage: 8.5 KB

# %%
Q1 = x["Ozone"].quantile(0.25)
Q3 = x["Ozone"].quantile(0.75)

# %%
IQR = Q3 - Q1

# %%
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

# %%
x = x[(x["Ozone"] >= lower) & (x["Ozone"] <= upper)]

# %%
x.shape
# Out:
# (144, 7)

# %%
x.boxplot(column=["Ozone"])
x_iqr.boxplot(column=["Ozone"])
plt.show()

# %%
x.boxplot(column=["Ozone", "Solar.R"])
plt.show()

# %%
x.boxplot(column=["Ozone"])
plt.show()

# %%
x_iqr.boxplot(column=["Ozone"])
plt.show()

# %%
x_cap = x.copy()
x_cap["Ozone"] = x_cap["Ozone"].clip(lower=lower, upper=upper)

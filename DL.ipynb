# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from mlxtend.plotting import plot_decision_regions

# %%
pip install mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
dataset = pd.read_csv(r"C:\Users\SRASHTIKA GAUTAM\OneDrive\Desktop\data\enriched_placement_dataset (1).csv")

# %%
dataset.head()
# Out:
#    cgpa  score  internships  skills  backlogs  certifications  communication  \
# 0  6.84   4.19            3       5         1               3           6.01
# 1  9.66   7.82            3       7         3               0           5.02
# 2  8.59   5.89            2       1         1               3           7.88
# 3  7.93   7.05            0       3         1               2           6.33
# 4  5.76   9.45            3       2         2               4           5.38
#
#    programming_score  extra_curricular gender domain  placed
# 0               5.08                 1   Male  CIVIL       0
# 1               8.18                 0   Male    ECE       0
# 2               6.47                 1   Male    ECE       0
# 3               9.25                 0   Male     CS       1
# 4               7.09                 1   Male     CS       0

# %%
dataset.shape
# Out:
# (100, 12)

# %%
plt.figure(figsize = (4,3))

# %%
sns.scatterplot(x="cgpa",y="score",data=dataset,hue = "placed")
# Out:
# <Axes: xlabel='cgpa', ylabel='score'>

# %%
plt.show()

# %%
x = dataset.iloc[:,:-1]
y = dataset["placed"]

# %%
dataset.drop(columns=["internships","skills","backlogs","certifications","communication","programming_score","extra_curricular","gender","domain"],inplace = True)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state = 42)

# %%
from sklearn.linear_model import Perceptron

# %%
from sklearn.preprocessing import LabelEncoder

# %%
dataset_encoder = dataset.copy()

# %%
for col in dataset_encoder.select_dtypes(include = "object").columns:
    dataset_encoder[col]=LabelEncoder().fit_transform(dataset_encoded[col])

# %%
# types of neural network
# perceptron
# Mlxtend
# model evaluation
# feature selection
# ensemble methods
# data visual.

# %%
x = dataset_encoder.drop("placed",axis = 1)
y = dataset_encoder["placed"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 9)

# %%
from  sklearn.linear_model import Perceptron
pr = Perceptron()
pr.fit(x_train,y_train)
# Out:
# Perceptron()

# %%
pr.score(x_train,y_train)*100,pr.score(x_test,y_test)*100
# Out:
# (55.00000000000001, 55.00000000000001)

# %%
plt.figure(figsize=(4,3))

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf = pr)
plt.show()
# Out:
# C:\Users\SRASHTIKA GAUTAM\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(

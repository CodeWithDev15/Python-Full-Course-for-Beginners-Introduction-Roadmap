# %%
a_a = 70
b_b = 80
print(not(a_a==b_b) or (a_a<b_b))
# Out:
# True

# %%
#eq = int to float
# int to string
a = 5
b = 5.0
print(a+b)
print(type(a+b))
print(type(a))
# There are two type of type converstions.
# This is a automatic type of convestion.
# Out:
# 10.0
# <class 'float'>
# <class 'int'>

# %%
a = 5
b = "5"
c = '5'
print(a+b)
print(a+c)
# we will get an error, because a string + int can not do a sum and string is use to display the data not to do a mathematical operation.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-2329266736> in <cell line: 0>()
#       2 b = "5"
#       3 c = '5'
# ----> 4 print(a+b)
#       5 print(a+c)
#       6 # we get an error because a string + int can not do sum because string is to display the heistes data not to do mathacial sum.
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a = 5
b = "10"
print(a+int(b))

# predefine, we have to give manual tyoe casting to a varbaibkle can't do on print time.
# Type converstion also have a limit and it cannot conver the string with int or int to string.
# Out:
# 15

# %%
# input statement is used to accept value from user.

name = input("enter your name = ")
print(name)
# Out:
# enter your name = Rehbar Khan
# Rehbar Khan

# %%
# input function by defualt consider any value as a string.
age = input("enter your age")
print(age)
print(type(age))
# Out:
# enter your age18
# 18
# <class 'str'>

# %%
#age = input("Enter your age")int.()
age = int(input("Enter your age")) # In
some interpeter it accpecets float numbers but most of the time you will se an error.
marks = float(input("Enter your marks"))

# Name, Age, Marks. # or you can do print("Wellcome, name[It will print your name and out will be like Welcome Rehbar Khan]")
name = inpiut("Enter your name")
print("Welcome", name)
# Out:
# Enter your age2
# Enter your marks2.5

# %%
a = 10
b = int("10")
print(a+b)
print(type(a+b))
# Out:
# 20
# <class 'int'>

# %%
age = input("Enter your age")
print(age)
print(type(age))
# Out:
# Enter your age18
# 18
# <class 'str'>

# %%
name = input("enter your name:" )
age = int(input("enter your age:" ))
marks = float(input("Enter your marks:" ))
print(name, age, marks)
# Out:
# enter your name:Rehbar Khan
# enter your age:18
# Enter your marks:25.5
# Rehbar Khan 18 25.5

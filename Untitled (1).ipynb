# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from mlxtend.plotting import plot_decision_regions

# %%
df = pd.read_csv('/Users/rehbarkhan15/Downloads/enriched_placement_dataset (1).csv')

# %%
df.head()
# Out:
#    cgpa  score  internships  skills  backlogs  certifications  communication  \
# 0  6.84   4.19            3       5         1               3           6.01
# 1  9.66   7.82            3       7         3               0           5.02
# 2  8.59   5.89            2       1         1               3           7.88
# 3  7.93   7.05            0       3         1               2           6.33
# 4  5.76   9.45            3       2         2               4           5.38
#
#    programming_score  extra_curricular gender domain  placed
# 0               5.08                 1   Male  CIVIL       0
# 1               8.18                 0   Male    ECE       0
# 2               6.47                 1   Male    ECE       0
# 3               9.25                 0   Male     CS       1
# 4               7.09                 1   Male     CS       0

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x=df['cgpa'],y=df['score'],hue=df['placed'])
# Out:
# <Axes: xlabel='cgpa', ylabel='score'>

# %%
x = df.iloc[::-1]
y = df['placed']

# %%
df = df.drop(columns=['internships','skills','backlogs','certifications','communication','programming_score','extra_curricular','gender','domain'])

# %%
df.head()
# Out:
#    cgpa  score  placed
# 0  6.84   4.19       0
# 1  9.66   7.82       0
# 2  8.59   5.89       0
# 3  7.93   7.05       1
# 4  5.76   9.45       0

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=9)

# %%
from sklearn.linear_model import Perceptron

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df_encoded = df.copy()

# %%
for col in df_encoded.select_dtypes(include='object').columns:
    df_encoded[col] = LabelEncoder().fit_transform(df_encoded[col])

# %%
x = df_encoded.drop('placed',axis=1)
y = df_encoded['placed']

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=9)

# %%
from sklearn.linear_model import Perceptron

# %%
pr = Perceptron()

# %%
pr.fit(x_train,y_train)
# Out:
# Perceptron()

# %%
pr.score(x_train,y_train)*100,pr.score(x_test,y_test)*100
# Out:
# (55.00000000000001, 55.00000000000001)

# %%
plt.figure(figsize=(4,3))

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=pr)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >

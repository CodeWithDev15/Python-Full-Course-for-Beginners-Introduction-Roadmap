# %%
x = "Rehbar"
y = "Khan"
print(x,y)
# Out:
# Rehbar Khan

# %%
x = "Rehbar"
y = "Khan"
print(x+" "+y)
# Out:
# Rehbar Khan

# %%
first_name = "Rehbar"
print(len(first_name)) #It prints the lenth of the variable that stores the string
# Out:
# 6

# %%
first_name = "Rehbar"
last_name = "Khan"
print(len(first_name+last_name))
# Out:
# 10

# %%
x = "Rehbar"
y = "Khan"
print(x+y)
# Out:
# RehbarKhan

# %%
x = "Rehbar"
y = "Khan"
print(x+" "+y) # here to add space between first and last name use "double cots and under space here python counts the space"
# Out:
# Rehbar Khan

# %%
age = int(input("Enter your age"))

if age >=18:
  print("You are allowed to participate")
else:
  print("You are under age and you are not allowed to particpiate")
# Out:
# Enter your age18
# You are allowed to participate

# %%
age = int(input("Enter your age!"))
if age <=16: # we skipeed 15,15 which falles under else:
  print("You are children my dear!")
elif age >=17 <=19:
  print("You are a teenager, enjoy your golden time!")
elif age >19 <=30:
  print("you are a adult!")
elif age >=30 <=60:
  print("you are so called adult!")
else:
  print("you are retired!")
# Out:
# Enter your age!20
# You are a teenager, enjoy your golden time!

# %%
age = int(input("Enter your age!"))

if 10 <= age <=12:
  print("You are a Preteen")
elif 12 <= age <=19:
  print("You are an Adult")
elif 20 <= age <=24:
  print("Often people waste thier life time")
else:
  print("you are old!")
  # Note we have not yet tell pythonn the 0 to 9 more than two vlaue sso it considers under else catoergy for more than or less than becuase these are untold vlaues to comund fall into under else
# Out:
# Enter your age!25
# you are old!

# %%
0 to 10
10 to 12
12 to 19
20 to 24
else cover rest of or you do after 60 is retired

# %%
age = int(input"Enter your age!")

if 0 <= age <=10:
  print("You are a children")
elif 10 <= age <=12:
  print("You are a preteen")
elif 12 <= age <=19: here should i use 12 to 19 or 13 to 19?
  print("You are a teen ager")
else:
  print("You are old ")

# %%
age = int(input("Enter your age!"))

if age <= 0:
  print("The age is Invalid!")
elif age <=10:
  print("You are a Children!")
elif age <= 12:
  print("You are a Preteen")
elif age <=19:
  print("You are a Teen ager")
elif age <=24:
  print("You are a Young adult")
elif age <=39:
  print("You are a Early Adulthood")
elif age <= 59:
  print("You are a Middle-Aged Adult")
elif 60 <= age <= 64:
  print(" You are a Older Adult (or Senior-to-be)")
elif age >=65:
  print("You are a Senior Citizen / Elderly")
# Out:
# Enter your age!66
# You are a Senior Citizen / Elderly

# %%
age = int(input("Enter your age!"))

if age <=0:
  print("The age is invalid!, please enter your correct age.")
elif 0 <= age <= 10:
  print("You are a children!")
elif 11 <= age <=13:
  print("You are a preeteen")
elif 14 <= age <=19:
  print("You are a adult")
else:
  print("You are old")
# Out:
# Enter your age!25
# You are old
